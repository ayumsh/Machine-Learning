# %% [markdown]
# I shall be honest in my efforts and will make my parents proud
# ![WhatsApp Image 2022-10-14 at 11.22.08 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![mle1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![mle2.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![map1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![map2.jpeg](data:image/jpeg;base64,...)

# %%
import numpy as np
from matplotlib import pyplot as plt


def f(x):
   return (x**42)*((1-x)**18)

x = np.linspace(0, 1, 100)
plt.xlabel('θ')
plt.ylabel('prior probablity')
plt.plot(x, f(x), color='red')

plt.show()

# %%
def g(x):
   return (x**48)*((1-x)**27)

x = np.linspace(0, 1, 100)
plt.xlabel('θ')
plt.ylabel('posterior probablity')
plt.plot(x, g(x), color='red')

plt.show()

# %% [markdown]
# ![WhatsApp Image 2022-10-14 at 10.49.22 PM.jpeg](data:image/jpeg;base64,...)

# %%
def h(x):
   return (x**486)*((1-x)**189)

x = np.linspace(0, 1, 100)
plt.xlabel('θ')
plt.ylabel('posterior probablity')
plt.plot(x, h(x), color='red')

plt.show()

# %%
def i(x):
   return (x**38)*((1-x)**37)

x = np.linspace(0, 1, 100)
plt.xlabel('θ')
plt.ylabel('posterior probablity')
plt.plot(x, h(x), color='red')

plt.show()

# %% [markdown]
# Plots in the 2nd example shows
# lower confidence in the prior assumption, by including only 60 = γ1 +γ0  imaginary data
# points
#
# whereas in the first example shows very high confidence in prior assumption
# 600 = γ1 +γ0
#
# graph in exapmle 2 is more spread out over values of θ than example 1
#
# θ will not change much for less ammount of training data in 1st case where 600 = γ1 +γ0 as compared to second
